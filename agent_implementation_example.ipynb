# %%
# %pip install -U langchain-community langgraph langchain-anthropic tavily-python langgraph-checkpoint-sqlite langchain-chroma langchainhub faiss-cpu
# Out:
# Requirement already satisfied: langchain-community in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.3.5)
# Requirement already satisfied: langgraph in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.2.44)
# Requirement already satisfied: langchain-anthropic in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: tavily-python in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: langgraph-checkpoint-sqlite in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: langchain-chroma in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: langchainhub in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.1.21)
# Requirement already satisfied: faiss-cpu in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (1.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: requests<3,>=2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: numpy<2,>=1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (3.10.10)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (0.1.139)
# Requirement already satisfied: langchain<0.4.0,>=0.3.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (0.3.7)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (2.0.35)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (0.3.15)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.32 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langgraph) (0.1.35)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langgraph) (2.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-anthropic) (2.9.2)
# Requirement already satisfied: anthropic<1,>=0.30.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-anthropic) (0.38.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-anthropic) (0.7.1)
# Requirement already satisfied: httpx in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from tavily-python) (0.27.2)
# Requirement already satisfied: tiktoken>=0.5.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from tavily-python) (0.8.0)
# Requirement already satisfied: aiosqlite<0.21.0,>=0.20.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langgraph-checkpoint-sqlite) (0.20.0)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-chroma) (0.5.17)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-chroma) (0.115.4)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchainhub) (24.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchainhub) (2.32.0.20241016)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.17.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: typing_extensions>=4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiosqlite<0.21.0,>=0.20.0->langgraph-checkpoint-sqlite) (4.12.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (0.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: sniffio in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (0.20.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (4.6.2.post1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (13.9.4)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.67.1)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.66.6)
# Requirement already satisfied: pypika>=0.48.9 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.2.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: importlib-resources in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (6.4.5)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.32.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.7.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (5.0.1)
# Requirement already satisfied: typer>=0.9.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.12.5)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.10.11)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (31.0.0)
# Requirement already satisfied: build>=1.0.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.41.2)
# Requirement already satisfied: httpcore==1.* in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx->tavily-python) (1.0.6)
# Requirement already satisfied: certifi in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx->tavily-python) (2024.8.30)
# Requirement already satisfied: idna in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx->tavily-python) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpcore==1.*->httpx->tavily-python) (0.14.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain<0.4.0,>=0.3.6->langchain-community) (0.3.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-community) (1.33)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.0->langgraph) (1.1.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from tiktoken>=0.5.1->tavily-python) (2024.9.11)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.30.0->langchain-anthropic) (1.2.2)
# Requirement already satisfied: tomli>=1.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.0.2)
# Requirement already satisfied: pyproject_hooks in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (8.4.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-community) (3.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.35.0)
# Requirement already satisfied: requests-oauthlib in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: six>=1.9.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: flatbuffers in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (24.3.25)
# Requirement already satisfied: sympy in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.13.1)
# Requirement already satisfied: coloredlogs in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: protobuf in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.25.5)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.14)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.65.0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (65.5.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.6.4)
# Requirement already satisfied: websockets>=10.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (13.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.24.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from importlib-resources->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.20.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (5.5.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.4.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (2024.9.0)
# Requirement already satisfied: filelock in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (3.16.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.6.1)
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_anthropic import ChatAnthropic
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import create_react_agent
# %pip install -U langchain langchain-openai
import os
# Out:
# Requirement already satisfied: langchain in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.3.7)
# Requirement already satisfied: langchain-openai in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.2.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (0.1.139)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (2.0.35)
# Requirement already satisfied: numpy<2,>=1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: requests<3,>=2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (3.10.10)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain) (0.3.15)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: openai<2.0.0,>=1.52.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-openai) (1.53.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.6.2.post1)
# Requirement already satisfied: tqdm>4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.66.6)
# Requirement already satisfied: sniffio in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: regex>=2022.1.18 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.52.0->langchain-openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = "x"  # getpass.getpass()
os.environ[
    "OPENAI_API_KEY"] = "x"
'''
LANGCHAIN_TRACING_V2=true
LANGCHAIN_ENDPOINT="https://api.smith.langchain.com"
LANGCHAIN_API_KEY="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"
LANGCHAIN_PROJECT="pr-worthwhile-escalator-78"
'''
# Out:
# '\nLANGCHAIN_TRACING_V2=true\nLANGCHAIN_ENDPOINT="https://api.smith.langchain.com"\nLANGCHAIN_API_KEY="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"\nLANGCHAIN_PROJECT="pr-worthwhile-escalator-78"\n'

# %%
# %pip install -qU "langchain-community>=0.2.11" tavily-python
if not os.environ.get("TAVILY_API_KEY"):
    os.environ["TAVILY_API_KEY"] = 'x'
# Out:
# python(18825) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create the agent
from langchain_openai import ChatOpenAI

memory = MemorySaver()
model = ChatOpenAI(model="gpt-4o")
search = TavilySearchResults(max_results=2)
tools = [search]
agent_executor = create_react_agent(model, tools, checkpointer=memory)
# Use the agent
config = {"configurable": {"thread_id": "abc123"}}
for chunk in agent_executor.stream(
        {"messages": [HumanMessage(content="hi im bob! and i live in sf")]}, config
):
    print(chunk)
    print("----")
# Out:
# python(18835) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# {'agent': {'messages': [AIMessage(content="Hi Bob! It's great to meet you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 88, 'total_tokens': 105, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_159d8341cc', 'finish_reason': 'stop', 'logprobs': None}, id='run-142253b0-4435-4bd4-8884-8bc940705ace-0', usage_metadata={'input_tokens': 88, 'output_tokens': 17, 'total_tokens': 105, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}})]}}
# ----

# %%
# %pip install -U langchain-chroma

from langchain.chains import llm
import bs4
from langchain import hub
from langchain_chroma import Chroma
from langchain_community.document_loaders import WebBaseLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Load, chunk and index the contents of the blog.
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
docs = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())

# Retrieve and generate using the relevant snippets of the blog.
retriever = vectorstore.as_retriever()
prompt = hub.pull("rlm/rag-prompt")


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = (
        {"context": retriever | format_docs, "question": RunnablePassthrough()}
        | prompt
        | model
        | StrOutputParser()
)

rag_chain.invoke("What is Task Decomposition?")
for chunk in agent_executor.stream(
        {"messages": [HumanMessage(content="whats the weather where I live?")]}, config
):
    print(chunk)
    print("----")
# https://python.langchain.com/docs/tutorials/agents/
# https://docs.smith.langchain.com/
#
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../../modules/state_of_the_union.txt")
documents = loader.load()
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(documents)
embeddings = OpenAIEmbeddings()
db = FAISS.from_documents(texts, embeddings)
retriever = db.as_retriever()
from langchain.tools.retriever import create_retriever_tool

tool = create_retriever_tool(
    retriever,
    "search_state_of_union",
    "Searches and returns excerpts from the 2022 State of the Union.",
)
tools = [tool]
# Out:
# python(19131) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Requirement already satisfied: langchain-chroma in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: langchain-core<0.4,>=0.1.40 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-chroma) (0.3.15)
# Requirement already satisfied: numpy<2,>=1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-chroma) (0.5.17)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-chroma) (0.115.4)
# Requirement already satisfied: overrides>=7.3.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (31.0.0)
# Requirement already satisfied: httpx>=0.27.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.27.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.20.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.10.11)
# Requirement already satisfied: typer>=0.9.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.12.5)
# Requirement already satisfied: importlib-resources in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (6.4.5)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (5.0.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.2.0)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.66.6)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (9.0.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: posthog>=2.4.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.7.0)
# Requirement already satisfied: build>=1.0.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.12.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.32.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (13.9.4)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (6.0.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: pydantic>=1.9 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.9.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.19.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.67.1)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.41.2)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-core<0.4,>=0.1.40->langchain-chroma) (24.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-core<0.4,>=0.1.40->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langchain-core<0.4,>=0.1.40->langchain-chroma) (0.1.139)
# Requirement already satisfied: tomli>=1.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.0.2)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (8.4.0)
# Requirement already satisfied: pyproject_hooks in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: idna in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.10)
# Requirement already satisfied: httpcore==1.* in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.0.6)
# Requirement already satisfied: sniffio in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.3.1)
# Requirement already satisfied: certifi in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2024.8.30)
# Requirement already satisfied: anyio in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.6.2.post1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1.40->langchain-chroma) (3.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: requests-oauthlib in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: six>=1.9.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: requests in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.32.3)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.35.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.2.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.1.40->langchain-chroma) (1.0.0)
# Requirement already satisfied: protobuf in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.25.5)
# Requirement already satisfied: flatbuffers in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (24.3.25)
# Requirement already satisfied: sympy in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.13.1)
# Requirement already satisfied: coloredlogs in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.14)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.27.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.65.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.48b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: setuptools>=16.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (65.5.1)
# Requirement already satisfied: asgiref~=3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: websockets>=10.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (13.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.0.1)
# Requirement already satisfied: httptools>=0.5.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.24.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from importlib-resources->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.20.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.4.1)
# Requirement already satisfied: filelock in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (2024.9.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from requests->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (3.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/pati/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma) (0.6.1)
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# {'agent': {'messages': [AIMessage(content="The weather in San Francisco is currently clear with a temperature of around 54°F (12.2°C). The wind is light, coming from the north at 4 mph (6.5 kph), and the humidity is 57%. It's a calm and clear night.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 784, 'total_tokens': 841, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_159d8341cc', 'finish_reason': 'stop', 'logprobs': None}, id='run-080ad559-f246-49c5-bb27-3afbdd181c80-0', usage_metadata={'input_tokens': 784, 'output_tokens': 57, 'total_tokens': 841, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}})]}}
# ----
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages/langchain_community/document_loaders/text.py:42, in TextLoader.lazy_load(self)
#      41 try:
# ---> 42     with open(self.file_path, encoding=self.encoding) as f:
#      43         text = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../modules/state_of_the_union.txt'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 56
#      53 from langchain_community.document_loaders import TextLoader
#      55 loader = TextLoader("../../modules/state_of_the_union.txt")
# ---> 56 documents = loader.load()
#      57 from langchain_community.vectorstores import FAISS
#      58 from langchain_openai import OpenAIEmbeddings
#
# File ~/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages/langchain_core/document_loaders/base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File ~/BenchMarkingRAGandAgentBasedRAG/lib/python3.9/site-packages/langchain_community/document_loaders/text.py:58, in TextLoader.lazy_load(self)
#      56         raise RuntimeError(f"Error loading {self.file_path}") from e
#      57 except Exception as e:
# ---> 58     raise RuntimeError(f"Error loading {self.file_path}") from e
#      60 metadata = {"source": str(self.file_path)}
#      61 yield Document(page_content=text, metadata=metadata)
#
# RuntimeError: Error loading ../../modules/state_of_the_union.txt
